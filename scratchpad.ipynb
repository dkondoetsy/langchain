# %% [markdown]
# <a href="https://colab.research.google.com/github/dkondoetsy/langchain/blob/master/scratchpad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Initial Evaluation Results of Gifting Agent

# %%
print("Hello, World!")
